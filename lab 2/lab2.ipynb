# %%
from PIL import Image
import glob, os,sys,PIL

# %%
#Different sizes correspond to different types
a = np.array([24, 12, 57], np.int8)
print(size(a) - 96)
a = np.array([24, 12, 57], np.int16)
print(size(a) - 96)
a = np.array([24, 12, 57], np.int32)
print(size(a) - 96)
a = np.array([24, 12, 57], np.int64)
print(size(a) - 96)
# Out:
# 3
# 6
# 12
# 24

# %%
#converting thumbnails
size = 128, 128
for infile in glob.glob("*.jpg"):
    file, ext = os.path.splitext(infile)
    im = Image.open(infile)
    im.thumbnail(size, Image.ANTIALIAS)
    im.save(file + ".thumbnail", "JPEG")

# %%
#Opening image and showing rotated and original image
im = Image.open("tempimg.jpg")
print im.format, im.size, im.mode
im.rotate(45).show()
im.show()
# Out:
# JPEG (1278, 1840) RGB

# %%
#Converting files to JPEG
images= ['Capture1.jpg','Capture.jpg','tempimg.jpg','cartoon2.png']
for infile in images: 
    f, e = os.path.splitext(infile) 
    outfile = f + ".jpg" 
    if infile != outfile: 
        try: 
            Image.open(infile).save(outfile) 
        except IOError: 
            print "cannot convert", infile

# %%
#new imports for next task
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
#RGB to Gray scale
img = Image.open('pp.png').convert('LA')
img.save('greyscale.png')

# %%
#Apply Smoothing Filter
from PIL import ImageFilter
im = Image.open("tempimg.jpg")
im1 = im.filter(ImageFilter.BLUR)
im1.show()

# %%
#Applying Sharpening Filter
im = Image.open("tempimg.jpg")
im1 = im.filter(ImageFilter.SHARPEN)
im1.show()

# %%
#Applying blur with cv2
import cv2

img = cv2.imread('pp.png')

blur = cv2.blur(img,(50,50))

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
#Implementing RGB to Grayscale
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def rgb_to_gray(img):
    grayImage = np.zeros(img.shape)
    R = np.array(img[:, :, 0])
    G = np.array(img[:, :, 1])
    B = np.array(img[:, :, 2])
    R = (R *.299)
    G = (G *.587)
    B = (B *.114)
    Avg = (R+G+B)
    grayImage = img
    for i in range(3):
            grayImage[:,:,i] = Avg
    return grayImage

image = mpimg.imread("pp.png")   
grayImage = rgb_to_gray(image)
type(grayImage)
plt.imshow(grayImage)
plt.show()

# %%
#ploting the graph
gray_image = cv2.imread("pp.png", cv2.IMREAD_GRAYSCALE)
plt.hist(gray_image .ravel(), bins=150)
plt.show()
